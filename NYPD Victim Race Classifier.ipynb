# %% [markdown]
# # NYPD Shootings

# %% [markdown]
# Classifying the victim's race (Asian or White) with latitude and longitude of the scene.

# %%
# Don't change this cell; just run it. 

import numpy as np
from datascience import * 

# These lines do some fancy plotting magic
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
import warnings
warnings.simplefilter('ignore')
from datetime import datetime

# %% [markdown]
# Read in data

# %%
shootings = Table.read_table('NYPD_Shooting_Incident_Data__Historic_.csv')
shootings.show(5)
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>INCIDENT_KEY</th> <th>OCCUR_DATE</th> <th>OCCUR_TIME</th> <th>BORO</th> <th>LOC_OF_OCCUR_DESC</th> <th>PRECINCT</th> <th>JURISDICTION_CODE</th> <th>LOC_CLASSFCTN_DESC</th> <th>LOCATION_DESC</th> <th>STATISTICAL_MURDER_FLAG</th> <th>PERP_AGE_GROUP</th> <th>PERP_SEX</th> <th>PERP_RACE</th> <th>VIC_AGE_GROUP</th> <th>VIC_SEX</th> <th>VIC_RACE</th> <th>X_COORD_CD</th> <th>Y_COORD_CD</th> <th>Latitude</th> <th>Longitude</th> <th>Lon_Lat</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>228798151   </td> <td>05/27/2021</td> <td>21:30:00  </td> <td>QUEENS</td> <td>nan              </td> <td>105     </td> <td>0                </td> <td>nan               </td> <td>nan          </td> <td>False                  </td> <td>nan           </td> <td>nan     </td> <td>nan      </td> <td>18-24        </td> <td>M      </td> <td>BLACK         </td> <td>1.05892e+06</td> <td>180924    </td> <td>40.663  </td> <td>-73.7308 </td> <td>POINT (-73.73083868899994 40.662964620000025)</td>
#         </tr>
#         <tr>
#             <td>137471050   </td> <td>06/27/2014</td> <td>17:40:00  </td> <td>BRONX </td> <td>nan              </td> <td>40      </td> <td>0                </td> <td>nan               </td> <td>nan          </td> <td>False                  </td> <td>nan           </td> <td>nan     </td> <td>nan      </td> <td>18-24        </td> <td>M      </td> <td>BLACK         </td> <td>1.00503e+06</td> <td>234516    </td> <td>40.8104 </td> <td>-73.9249 </td> <td>POINT (-73.92494232599995 40.81035186300006) </td>
#         </tr>
#         <tr>
#             <td>147998800   </td> <td>11/21/2015</td> <td>03:56:00  </td> <td>QUEENS</td> <td>nan              </td> <td>108     </td> <td>0                </td> <td>nan               </td> <td>nan          </td> <td>True                   </td> <td>nan           </td> <td>nan     </td> <td>nan      </td> <td>25-44        </td> <td>M      </td> <td>WHITE         </td> <td>1.00767e+06</td> <td>209837    </td> <td>40.7426 </td> <td>-73.9155 </td> <td>POINT (-73.91549174199997 40.74260663300004) </td>
#         </tr>
#         <tr>
#             <td>146837977   </td> <td>10/09/2015</td> <td>18:30:00  </td> <td>BRONX </td> <td>nan              </td> <td>44      </td> <td>0                </td> <td>nan               </td> <td>nan          </td> <td>False                  </td> <td>nan           </td> <td>nan     </td> <td>nan      </td> <td><18          </td> <td>M      </td> <td>WHITE HISPANIC</td> <td>1.00654e+06</td> <td>244511    </td> <td>40.8378 </td> <td>-73.9195 </td> <td>POINT (-73.91945661499994 40.83778200300003) </td>
#         </tr>
#         <tr>
#             <td>58921844    </td> <td>02/19/2009</td> <td>22:58:00  </td> <td>BRONX </td> <td>nan              </td> <td>47      </td> <td>0                </td> <td>nan               </td> <td>nan          </td> <td>True                   </td> <td>25-44         </td> <td>M       </td> <td>BLACK    </td> <td>45-64        </td> <td>M      </td> <td>BLACK         </td> <td>1.02492e+06</td> <td>262189    </td> <td>40.8862 </td> <td>-73.8529 </td> <td>POINT (-73.85290950899997 40.88623791800006) </td>
#         </tr>
#     </tbody>
# </table>
# <p>... (27307 rows omitted)</p>

# %%
shootings.group('VIC_RACE')
# Out:
# VIC_RACE                       | count
# AMERICAN INDIAN/ALASKAN NATIVE | 10
# ASIAN / PACIFIC ISLANDER       | 404
# BLACK                          | 19439
# BLACK HISPANIC                 | 2646
# UNKNOWN                        | 66
# WHITE                          | 698
# WHITE HISPANIC                 | 4049

# %%
shootings = shootings.select('Latitude', 'Longitude', 'VIC_RACE')
shootings = shootings.where('VIC_RACE', are.contained_in('ASIAN / PACIFIC ISLANDERWHITE'))

# %%
shootings = shootings.where('Latitude', are.between_or_equal_to(40,41))
shootings = shootings.where('Longitude', are.between_or_equal_to(-75,41))

# %% [markdown]
# Map of shootings

# %%
# Just run this cell!
colors = {"ASIAN / PACIFIC ISLANDER":"red", "WHITE":"blue"}
t = Table().with_columns("lat", shootings.column(0), 
                                      "lon", shootings.column(1), 
                                      "color", shootings.apply(colors.get, 2)
                        )
Circle.map_table(t, radius=2, fill_opacity=1)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c4790980e17a9904ab78ef354bb925f3 {
#                     position: relative;
#                     width: 960.0px;
#                     height: 500.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c4790980e17a9904ab78ef354bb925f3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c4790980e17a9904ab78ef354bb925f3 = L.map(
#                 &quot;map_c4790980e17a9904ab78ef354bb925f3&quot;,
#                 {
#                     center: [40.704842078500064, -73.97567483299994],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     clusteredMarker: false,
#                     includeColorScaleOutliers: true,
#                     radiusInMeters: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_61eab8f15083e1622751acf24f35c9e1 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 17, &quot;maxZoom&quot;: 17, &quot;minZoom&quot;: 8, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c4790980e17a9904ab78ef354bb925f3);
#
#
#             var circle_marker_66a49536085426763fd051257be469de = L.circleMarker(
#                 [40.74260663300004, -73.91549174199997],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c4790980e17a9904ab78ef354bb925f3);
#
#
#         var popup_9195944d3f86bace2be981bd300e2b30 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_86839d7a1426bb693f7fd89618072b75 = $(`&lt;div id=&quot;html_86839d7a1426bb693f7fd89618072b75&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;/div&gt;`)[0];
#             popup_9195944d3f86bace2be981bd300e2b30.setContent(html_86839d7a1426bb693f7fd89618072b75);
#
#
#         circle_marker_66a49536085426763fd051257be469de.bindPopup(popup_9195944d3f86bace2be981bd300e2b30)
#         ;
#
#
#
#
#             var circle_marker_f334d4e81c8b68e2fe05347e14056e3b = L.circleMarker(
#                 [40.88449492200005, -73.90559937499995],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c4790980e17a9904ab78ef354bb925f3);
#
#
#         var popup_4861944f33124646eb4ae85901994877 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_148acec8ea5e0da994b185a7ff9eaf03 = $(`&lt;div id=&quot;html_148acec8ea5e0da994b185a7ff9eaf03&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;/div&gt;`)[0];
#             popup_4861944f33124646eb4ae85901994877.setContent(html_148acec8ea5e0da994b185a7ff9eaf03);
#
#
#         circle_marker_f334d4e81c8b68e2fe05347e14056e3b.bindPopup(popup_4861944f33124646eb4ae85901994877)
#         ;
#
#
#
#
#             var circle_marker_9f97f5f620aa893a88f4a26643ade6a5 = L.circleMarker(
#                 [40.65735150300002, -73.95840237599998],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c4790980e17a9904ab78ef354bb925f3);
#
#
#         var popup_dde9c7f476512d76e7cbbce67bbb9e6a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_dbb6fc0e51778dd27aad521818b6b1ab = $(`&lt;div id=&quot;html_dbb6fc0e51778dd27aad521818b6b1ab&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;/div&gt;`)[0];
#             popup_dde9c7f476512d76e7cbbce67bbb9e6a.setContent(html_dbb6fc0e51778dd27aad521818b6b1ab);
#
#
#         circle_marker_9f97f5f620aa893a88f4a26643ade6a5.bindPopup(popup_dde9c7f476512d76e7cbbce67bbb9e6a)
#         ;
#
#
#
#
#             var circle_marker_13020a4f2d734da8f619920ad6bf70ae = L.circleMarker(
#                 [40.70103042700004, -73.94221368099994],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &

# %%
#shootings = shootings.sample(2000)
shootings
# Out:
# Latitude | Longitude | VIC_RACE
# 40.7426  | -73.9155  | WHITE
# 40.8845  | -73.9056  | WHITE
# 40.6574  | -73.9584  | WHITE
# 40.701   | -73.9422  | WHITE
# 40.7001  | -73.9477  | ASIAN / PACIFIC ISLANDER
# 40.7726  | -73.9159  | WHITE
# 40.7547  | -73.9916  | WHITE
# 40.6878  | -73.9132  | WHITE
# 40.7025  | -73.8138  | ASIAN / PACIFIC ISLANDER
# 40.8475  | -73.8273  | WHITE
# ... (1092 rows omitted)

# %%
def distance(arr1, arr2):
    return np.sqrt(sum((arr1 - arr2)**2))

# %%
shootings.num_rows
# Out:
# 1102

# %%
shuffled_table = shootings.sample(with_replacement=False)
train = shuffled_table.take(np.arange(826))
test = shuffled_table.take(np.arange(826, 1102))

print("Training set:\t",   train.num_rows, "examples")
print("Test set:\t",       test.num_rows, "examples")
train.show(5), test.show(5);
# Out:
# Training set:	 826 examples
# Test set:	 276 examples
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>Latitude</th> <th>Longitude</th> <th>VIC_RACE</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>40.6874 </td> <td>-73.977  </td> <td>ASIAN / PACIFIC ISLANDER</td>
#         </tr>
#         <tr>
#             <td>40.8722 </td> <td>-73.8661 </td> <td>ASIAN / PACIFIC ISLANDER</td>
#         </tr>
#         <tr>
#             <td>40.6288 </td> <td>-73.9366 </td> <td>WHITE                   </td>
#         </tr>
#         <tr>
#             <td>40.6963 </td> <td>-73.8546 </td> <td>WHITE                   </td>
#         </tr>
#         <tr>
#             <td>40.5603 </td> <td>-74.1103 </td> <td>WHITE                   </td>
#         </tr>
#     </tbody>
# </table>
# <p>... (821 rows omitted)</p>
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>Latitude</th> <th>Longitude</th> <th>VIC_RACE</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>40.707  </td> <td>-73.9046 </td> <td>WHITE   </td>
#         </tr>
#         <tr>
#             <td>40.8575 </td> <td>-73.8968 </td> <td>WHITE   </td>
#         </tr>
#         <tr>
#             <td>40.6762 </td> <td>-73.9513 </td> <td>WHITE   </td>
#         </tr>
#         <tr>
#             <td>40.7467 </td> <td>-73.7069 </td> <td>WHITE   </td>
#         </tr>
#         <tr>
#             <td>40.8345 </td> <td>-73.9266 </td> <td>WHITE   </td>
#         </tr>
#     </tbody>
# </table>
# <p>... (271 rows omitted)</p>

# %%
features = make_array("Latitude", "Longitude")
features
# Out:
# array(['Latitude', 'Longitude'],
#       dtype='<U9')

# %%
def row_to_array(row, features):
    """Converts a row to an array of its features."""
    arr = make_array()
    for feature in features:
        arr = np.append(arr, row.item(feature))
    return arr

def classify(test_row, k, train):
    test_row_features_array = row_to_array(test_row, features)
    distances = make_array()
    for train_row in train.rows:
        train_row_features_array = row_to_array(train_row, features)
        row_distance = distance(train_row_features_array, test_row_features_array)
        distances = np.append(distances, row_distance)
    train_with_distances = train.with_column("Distance", distances)
    nearest_neighbors = train_with_distances.sort("Distance").take(np.arange(k))
    most_common_label = nearest_neighbors.group("VIC_RACE").sort('count', descending = True).column(0).item(0)
    return most_common_label

# %%
first_test = classify(test.row(0), 5, train)
first_test
# Out:
# 'WHITE'

# %%
def three_classify(row):
    return classify(row, 3, train)

test_with_prediction = test.apply(three_classify)
labels_correct = np.count_nonzero(test_with_prediction == test.column("VIC_RACE"))
accuracy = labels_correct / test.num_rows
accuracy
# Out:
# 0.6884057971014492

# %%
for i in np.arange(1, 10):
    def k_classify(row):
        return classify(row, i, train)
    test_with_prediction = test.apply(three_classify)
    labels_correct = np.count_nonzero(test_with_prediction == test.column("VIC_RACE"))
    accuracy = labels_correct / test.num_rows
    print(accuracy)
# Out:
# 0.7282608695652174
# 0.6847826086956522
# 0.6884057971014492
# 0.6594202898550725
# 0.6811594202898551
# 0.6630434782608695
# 0.6884057971014492
# 0.6811594202898551
# 0.6847826086956522

# %%
for i in np.arange(10, 21):
    def k_classify(row):
        return classify(row, i, train)
    test_with_prediction = test.apply(three_classify)
    labels_correct = np.count_nonzero(test_with_prediction == test.column("VIC_RACE"))
    accuracy = labels_correct / test.num_rows
    print(accuracy)
# Out:
# 0.6884057971014492
# 0.6739130434782609
# 0.6811594202898551
# 0.6702898550724637
# 0.7028985507246377
# 0.6992753623188406
# 0.7101449275362319
# 0.6992753623188406
# 0.7137681159420289
# 0.7028985507246377
# 0.7028985507246377

# %% [markdown]
# Which k to use?
